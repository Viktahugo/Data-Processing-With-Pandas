# %%
import pandas as pd

# %%
df=pd.read_csv("train_titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Creating a Data Frame

# %%
import numpy as np
df1=pd.DataFrame([[1,2,3],[4,5,6],[7,np.nan,8],[9,10,np.nan]])

# %%
df1
# Out:
#    0     1    2
# 0  1   2.0  3.0
# 1  4   5.0  6.0
# 2  7   NaN  8.0
# 3  9  10.0  NaN

# %%
df1.dropna(how='all')
# Out:
#    0     1    2
# 0  1   2.0  3.0
# 1  4   5.0  6.0
# 2  7   NaN  8.0
# 3  9  10.0  NaN

# %%
df1.dropna(axis=1)
# Out:
#    0
# 0  1
# 1  4
# 2  7
# 3  9

# %%
df1
# Out:
#    0     1    2
# 0  1   2.0  3.0
# 1  4   5.0  6.0
# 2  7   NaN  8.0
# 3  9  10.0  NaN

# %%
df1.dropna(axis=1,thresh=2)
# Out:
#    0     1    2
# 0  1   2.0  3.0
# 1  4   5.0  6.0
# 2  7   NaN  8.0
# 3  9  10.0  NaN

# %%
df1.dropna()
# Out:
#    0    1    2
# 0  1  2.0  3.0
# 1  4  5.0  6.0

# %%
df1.dropna(thresh=2)
# Out:
#    0     1    2
# 0  1   2.0  3.0
# 1  4   5.0  6.0
# 2  7   NaN  8.0
# 3  9  10.0  NaN

# %%
df1.dropna(thresh=2)
# Out:
#    0     1    2
# 0  1   2.0  3.0
# 1  4   5.0  6.0
# 2  7   NaN  8.0
# 3  9  10.0  NaN

# %% [markdown]
# # Filling Missing Values

# %%
df1.fillna(0)
# Out:
#    0     1    2
# 0  1   2.0  3.0
# 1  4   5.0  6.0
# 2  7   0.0  8.0
# 3  9  10.0  0.0

# %%
df1
# Out:
#    0     1    2
# 0  1   2.0  3.0
# 1  4   5.0  6.0
# 2  7   NaN  8.0
# 3  9  10.0  NaN

# %%
df1.fillna(0)
# Out:
#    0     1    2
# 0  1   2.0  3.0
# 1  4   5.0  6.0
# 2  7   0.0  8.0
# 3  9  10.0  0.0

# %%
df1.fillna({0:1,1:3,2:11})
# Out:
#    0     1     2
# 0  1   2.0   3.0
# 1  4   5.0   6.0
# 2  7   3.0   8.0
# 3  9  10.0  11.0

# %%
df1.fillna({2:11})
# Out:
#    0     1     2
# 0  1   2.0   3.0
# 1  4   5.0   6.0
# 2  7   NaN   8.0
# 3  9  10.0  11.0

# %%
df1.fillna(method="ffill")
# Out:
#    0     1    2
# 0  1   2.0  3.0
# 1  4   5.0  6.0
# 2  7   5.0  8.0
# 3  9  10.0  8.0

# %%
df1
# Out:
#    0     1    2
# 0  1   2.0  3.0
# 1  4   5.0  6.0
# 2  7   NaN  8.0
# 3  9  10.0  NaN

# %%
df1.fillna(axis=1,method="ffill")
# Out:
#      0     1     2
# 0  1.0   2.0   3.0
# 1  4.0   5.0   6.0
# 2  7.0   7.0   8.0
# 3  9.0  10.0  10.0

# %%
df1.fillna(method="ffill")
# Out:
#    0     1    2
# 0  1   2.0  3.0
# 1  4   5.0  6.0
# 2  7   5.0  8.0
# 3  9  10.0  8.0

# %%
df1
# Out:
#    0     1    2
# 0  1   2.0  3.0
# 1  4   5.0  6.0
# 2  7   NaN  8.0
# 3  9  10.0  NaN

# %%
df1.fillna(df1.mean(0))
# Out:
#    0          1         2
# 0  1   2.000000  3.000000
# 1  4   5.000000  6.000000
# 2  7   5.666667  8.000000
# 3  9  10.000000  5.666667

# %%
df1
# Out:
#    0     1    2
# 0  1   2.0  3.0
# 1  4   5.0  6.0
# 2  7   NaN  8.0
# 3  9  10.0  NaN

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mean_age=df["Age"].mean()

# %%
df["Age"].fillna(mean_age)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df=df.fillna(df.mean())

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data = pd.Series([1,2,-99,4,5,-99,7,8,-99])

# %%
data
# Out:
# 0     1
# 1     2
# 2   -99
# 3     4
# 4     5
# 5   -99
# 6     7
# 7     8
# 8   -99
# dtype: int64

# %%
data.replace(-99,np.nan)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    5.0
# 5    NaN
# 6    7.0
# 7    8.0
# 8    NaN
# dtype: float64

# %%
data
# Out:
# 0     1
# 1     2
# 2   -99
# 3     4
# 4     5
# 5   -99
# 6     7
# 7     8
# 8   -99
# dtype: int64

# %%
new_data = pd.Series([-100,11,12,13])

# %%
new_data
# Out:
# 0   -100
# 1     11
# 2     12
# 3     13
# dtype: int64

# %%
combined_data = pd.concat([data,new_data],ignore_index=True)

# %%
combined_data1 = pd.concat([data,new_data])

# %%
combined_data
# Out:
# 0       1
# 1       2
# 2     -99
# 3       4
# 4       5
# 5     -99
# 6       7
# 7       8
# 8     -99
# 9    -100
# 10     11
# 11     12
# 12     13
# dtype: int64

# %%
combined_data1
# Out:
# 0      1
# 1      2
# 2    -99
# 3      4
# 4      5
# 5    -99
# 6      7
# 7      8
# 8    -99
# 0   -100
# 1     11
# 2     12
# 3     13
# dtype: int64

# %%
combined_data3=pd.concat([new_data,data])

# %%
combined_data3
# Out:
# 0   -100
# 1     11
# 2     12
# 3     13
# 0      1
# 1      2
# 2    -99
# 3      4
# 4      5
# 5    -99
# 6      7
# 7      8
# 8    -99
# dtype: int64

# %%
data_replaced = combined_data3.replace(-99,np.nan)

# %%
data_replaced
# Out:
# 0   -100.0
# 1     11.0
# 2     12.0
# 3     13.0
# 0      1.0
# 1      2.0
# 2      NaN
# 3      4.0
# 4      5.0
# 5      NaN
# 6      7.0
# 7      8.0
# 8      NaN
# dtype: float64

# %%
data_number = pd.DataFrame({'english':['zero','one','two','three','four','five'],'digits':[0,1,2,3,4,5]})

# %%
data_number
# Out:
#   english  digits
# 0    zero       0
# 1     one       1
# 2     two       2
# 3   three       3
# 4    four       4
# 5    five       5

# %%
english_to_multiple = {'two':'yes','four':'yes'}

# %%
data_number['multiple'] = data_number['english'].map(english_to_multiple)

# %%
data_number
# Out:
#   english  digits multiple
# 0    zero       0      NaN
# 1     one       1      NaN
# 2     two       2      yes
# 3   three       3      NaN
# 4    four       4      yes
# 5    five       5      NaN

# %%
data_number['crazy'] = 'NaN'

# %%
data_number
# Out:
#   english  digits multiple crazy
# 0    zero       0      NaN   NaN
# 1     one       1      NaN   NaN
# 2     two       2      yes   NaN
# 3   three       3      NaN   NaN
# 4    four       4      yes   NaN
# 5    five       5      NaN   NaN

# %%
data_number = data_number.iloc[:,[0,1,2]]

# %%
data_number
# Out:
#   english  digits multiple
# 0    zero       0      NaN
# 1     one       1      NaN
# 2     two       2      yes
# 3   three       3      NaN
# 4    four       4      yes
# 5    five       5      NaN

# %%
data_number.fillna(method='bfill')
# Out:
#   english  digits multiple
# 0    zero       0      yes
# 1     one       1      yes
# 2     two       2      yes
# 3   three       3      yes
# 4    four       4      yes
# 5    five       5      NaN

# %%
prime_number={'one':'yes','two':'yes','five':'yes'}

# %%
data_number['prime_number'] = data_number['english'].map(prime_number)

# %%
data_number
# Out:
#   english  digits multiple prime_number
# 0    zero       0      NaN          NaN
# 1     one       1      NaN          yes
# 2     two       2      yes          yes
# 3   three       3      NaN          NaN
# 4    four       4      yes          NaN
# 5    five       5      NaN          yes

# %%
even_number = {'zero':'yes','two':'yes','four':'yes'}

# %%
data_number['even_number'] = data_number['english'].map(even_number)

# %%
data_number
# Out:
#   english  digits multiple prime_number even_number
# 0    zero       0      NaN          NaN         yes
# 1     one       1      NaN          yes         NaN
# 2     two       2      yes          yes         yes
# 3   three       3      NaN          NaN         NaN
# 4    four       4      yes          NaN         yes
# 5    five       5      NaN          yes         NaN

# %%
import random

# %%
data = random.sample(range(1,101),30)

# %%
data1 = pd.Series(data)

# %%
data1
# Out:
# 0     93
# 1     38
# 2      3
# 3     73
# 4     41
# 5     96
# 6     97
# 7     88
# 8     33
# 9     23
# 10    42
# 11    43
# 12    60
# 13    59
# 14    55
# 15    22
# 16     2
# 17    13
# 18    86
# 19    20
# 20    17
# 21    53
# 22    44
# 23    94
# 24    83
# 25    39
# 26    66
# 27    24
# 28    51
# 29    91
# dtype: int64

# %%
#Cut Function

bucket = [1,20,22,25,49]
cut_data = pd.cut(data,bucket)

# %%
cut_data
# Out:
# [NaN, (25.0, 49.0], (1.0, 20.0], NaN, (25.0, 49.0], ..., (25.0, 49.0], NaN, (22.0, 25.0], NaN, NaN]
# Length: 30
# Categories (4, interval[int64]): [(1, 20] < (20, 22] < (22, 25] < (25, 49]]

# %%
data1
# Out:
# 0     93
# 1     38
# 2      3
# 3     73
# 4     41
# 5     96
# 6     97
# 7     88
# 8     33
# 9     23
# 10    42
# 11    43
# 12    60
# 13    59
# 14    55
# 15    22
# 16     2
# 17    13
# 18    86
# 19    20
# 20    17
# 21    53
# 22    44
# 23    94
# 24    83
# 25    39
# 26    66
# 27    24
# 28    51
# 29    91
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df
